# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
RecallRate = pd.read_csv(r"F:\\24561\\Documents\\欧贝杯智能创新比赛\\数据\\Weight&Recalltest.csv")
RecallRate = pd.DataFrame(data=RecallRate)

# %%
def plot_concrete_entre_dischange(RecallRate,entre):
    chooseweight = RecallRate[RecallRate['Entre']==entre]
    weightDis = np.asarray(chooseweight.iloc[:,1])
    recallObject = np.asarray(chooseweight.iloc[:,3])
    recallObject = recallObject.astype('float64')

    plt.plot(weightDis,recallObject,color="green",label="Recallrate")
    plt.xticks(weightDis)
    plt.xticks(rotation = 45)
    plt.legend()
    plt.xlabel("距离的权重")
    plt.ylabel("测试集上召回率")
    plt.title("测试集上固定企业资质权重为{}时召回率随距离权重的变化的学习曲线".format(entre))
    plt.show()

# %%
entre = 0.4
plot_concrete_entre_dischange(RecallRate,entre)

# %%
recallObject
# Out:
# array([0.19211698, 0.19485765, 0.19552478, 0.19545266, 0.19536251,
#        0.19520023, 0.19478552, 0.19474946, 0.19727376, 0.19768847,
#        0.19729179, 0.19761634, 0.19709345, 0.1967689 , 0.19619192,
#        0.19550675, 0.19438885, 0.19346928])

# %%
recallObject.dtype
# Out:
# dtype('float64')
